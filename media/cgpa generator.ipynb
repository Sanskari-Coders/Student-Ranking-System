# %%
import pandas as pd
import random
data=pd.read_excel("ranks.xlsx")

# %%
def fillout(x):
    if pd.isnull(x):
        newGPA=random.uniform(6,9)
        return round(newGPA,2)
    else:
        return x

# %%
data['CGPA']=data['CGPA'].apply(fillout)

# %%
data['SGPA']=data['SGPA'].apply(fillout)

# %%
def change(y):
    #sem=random.randint(1,6)
    sem=6
    return sem

# %%
data['SEMESTER']=data['SEMESTER'].apply(change)

# %%
data
# Out:
#     STUDENT REGISTRATION NUMBER          STUDENT NAME DEPARTMENT  SEMESTER  \
# 0                  210614100001           SUBRAT SAHU        BCA         6
# 1                  210614100002          SUMIT TIRKEY        BCA         6
# 2                  210614100003            TAPAS DASH        BCA         6
# 3                  210614100004        TARANISEN BHOI        BCA         6
# 4                  210614100005         ARYAMAN SAHOO        BCA         6
# 5                  210614100007           BABUL KARNA        BCA         6
# 6                  210614100008    BIJAYANI BIDYADHAR        BCA         6
# 7                  210614100009           BIKASH RANA        BCA         6
# 8                  210614100010        GANGADHAR ROUT        BCA         6
# 9                  210614100011           HARESH SAHU        BCA         6
# 10                 210614100012      HRITIK MAHANANDA        BCA         6
# ...

# %%
data.to_excel("anishh.xlsx",index=False)
